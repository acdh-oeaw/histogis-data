# %%
import os
import glob
import json
from histogis.histogis import HistoGis

# %%
try:
    os.mkdir('single_files')
except FileExistsError:
    pass

# %%
dump = HistoGis().dump_all_file_per_feature(path='single_files')
# Out:
# single_files/osterreich__1815-06-09_1846-11-16.geojson
# single_files/osterreich__1846-11-17_1859-10-11.geojson
# single_files/osterreich__1859-10-12_1866-10-03.geojson
# single_files/osterreich__1866-10-04_1867-12-21.geojson
# single_files/erzherzogtum-osterreich-unter-der-enns__1815-06-09_1867-12-21.geojson
# single_files/konigreich-slawonien__1815-06-09_1849-11-18.geojson
# single_files/herzogtum-steiermark__1815-06-09_1867-12-21.geojson
# single_files/herzogtum-ober-und-niederschlesien__1815-06-09_1867-12-21.geojson
# single_files/konigreich-dalmatien__1815-06-09_1867-12-21.geojson
# single_files/grofurstentum-siebenburgen__1815-06-09_1867-12-21.geojson
# single_files/konigreich-lombardo-venetien__1815-06-09_1850-12-31.geojson
# single_files/erzherzogtum-osterreich-ob-der-enns__1815-06-09_1849-03-04.geojson
# single_files/konigreich-galizien-und-lodomerien__1815-06-09_1846-11-15.geojson
# ...

# %%
def merge_single_files(self, file='histogis-dump-test.jsonl', source_path='single_files', verbose=True):
    """
    writes all geojson from the given folder into a JSONL file
    :path: Path to folder containing the .geojson files
    :return: A JSONL file.
    """
    files = sorted(glob.glob(f"./{singel_files}/*.geojson"))
    with open(file, 'w', encoding="utf-8") as f:
        for x in files
            with open(x) as json_file:
                data = json.load(json_file)
                f.write(f"{json.dumps(data)}\n")
    return file

# %%
with open('histogis-dump.jsonl', 'w', encoding="utf-8") as f:
    for x in files:
        with open(x) as json_file:
            data = json.load(json_file)
            f.write(f"{json.dumps(data)}\n")
